# %% [markdown]
# ## Week 2
#
# Please print your name and your NIM.

# %%
# here
nama = "Belinda Putri Adi Permana"
nim = "0706022210014"
print("{} - {}".format(nama, nim))
# Out:
# Belinda Putri Adi Permana - 0706022210014

# %% [markdown]
# ## Pandas

# %% [markdown]
# Please import the necessary library here.

# %%
# Import Library
import pandas as pd

# %% [markdown]
# <h1> Import Data

# %% [markdown]
# Please download the data from Elearn. <br>
# then input the data from:
# 1. CSV File
# 2. Excel File
# 3. JSON File
# 4. Text File, add header 'English' and 'France'
# 5. Web Dataset - https://raw.githubusercontent.com/michellechandraa/TutorDataMining/refs/heads/main/menu.csv
#
# into the dataframe

# %%
# 1
csv_path = r'C:\Users\Belinda\Documents\Belinda\1. Tugas\Data Mining\Ice Cream Sales and Temperature.csv'
csv = pd.read_csv(csv_path)
csv.head()
# Out:
#          Date   Time  Temperature (Celsius)  Ice Cream Sales
# 0  2023-01-01  08:00                     18               20
# 1  2023-01-01  08:05                     19               22
# 2  2023-01-01  08:10                     20               25
# 3  2023-01-01  08:15                     21               24
# 4  2023-01-01  08:20                     22               26

# %%
# 2
excel_path = r'C:\Users\Belinda\Documents\Belinda\1. Tugas\Data Mining\Maven Business School.xlsx'
excel = pd.read_excel(excel_path)
excel.head()
# Out:
#    Student ID  Undergrad Degree  Undergrad Grade  MBA Grade Work Experience  \
# 0           1          Business             68.4       90.2              No
# 1           2          Business             62.1       92.8              No
# 2           3  Computer Science             70.2       68.7             Yes
# 3           4       Engineering             75.1       80.7              No
# 4           5           Finance             60.9       74.9              No
#
#    Employability (Before)  Employability (After)      Status  Annual Salary
# 0                   252.0                  276.0      Placed       111000.0
# 1                   423.0                  410.0  Not Placed            NaN
# 2                   101.0                  119.0      Placed       107000.0
# 3                   288.0                  334.0  Not Placed            NaN
# 4                   248.0                  252.0  Not Placed            NaN

# %%
# 3
json_path = r'C:\Users\Belinda\Documents\Belinda\1. Tugas\Data Mining\drake_data.json'
json = pd.read_json(json_path)
json.head()
# Out:
#                  album                           lyrics_title  \
# 0  Certified Lover Boy            Certified Lover Boy* Lyrics
# 1  Certified Lover Boy  Like I’m Supposed To/Do Things Lyrics
# 2  Certified Lover Boy                      Not Around Lyrics
# 3  Certified Lover Boy    In the Cut (Ft. Roddy Ricch) Lyrics
# 4  Certified Lover Boy  Zodiac Sign (Ft. Jessie Reyez) Lyrics
#
#                                           lyrics_url  \
# 0  https://genius.com/Drake-certified-lover-boy-l...
# 1  https://genius.com/Drake-like-im-supposed-to-d...
# 2         https://genius.com/Drake-not-around-lyrics
# 3         https://genius.com/Drake-in-the-cut-lyrics
# 4        https://genius.com/Drake-zodiac-sign-lyrics
#
#                                               lyrics track_views
# 0  Lyrics from CLB Merch\n\n[Verse]\nPut my feeli...        8.7K
# 1  [Verse]\nHands are tied\nSomeone's in my ear f...       38.8K
# 2  [Intro]\nYeah, we back\nWassup ladies?\nSwisha...      129.8K
# 3  [Intro: Drake]\nAyy, yeah\nPipe this shit up a...       72.1K
# 4  [Verse 1: Drake]\nYou ask how many girls I bee...       54.8K

# %%
# 4
txt_path = r'C:\Users\Belinda\Documents\Belinda\1. Tugas\Data Mining\eng-fra.txt'
txt = pd.read_table(txt_path)   
txt = txt.rename(columns={'Go.':'English', 'Va !':'France'})
txt.sample(n = 5)
# Out:
#                                    English  \
# 45296             They are going shopping.
# 97456  They brought trouble on themselves.
# 41566              You people are amazing.
# 31579                You're such an idiot!
# 93321   Once you begin, you must continue.
#
#                                               France
# 45296                    Ils vont faire les courses.
# 97456                Ils se sont attirés des ennuis.
# 41566                         Vous êtes incroyables.
# 31579                      Quelle idiote vous êtes !
# 93321  Une fois que tu commences, tu dois continuer.

# %%
# 5
url_path = r'https://raw.githubusercontent.com/michellechandraa/TutorDataMining/refs/heads/main/menu.csv'
url = pd.read_csv(url_path)
url.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 0                             25        0.0  ...             31
# 1                             15        0.0  ...             30
# 2                             42        0.0  ...             29
# 3                             52        0.0  ...             30
# 4                             42        0.0  ...             30
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                             10              4
# 1                             10              4
# 2                             10              4
# 3                             10              4
# 4                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                             17       3       17                         10
# 1                             17       3       18                          6
# 2                             17       2       14                          8
# 3                             17       2       21                         15
# 4                             17       2       21                          6
#
#    Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 0                          0                       25                    15
# 1                          0                       25                     8
# 2                          0                       25                    10
# 3                          0                       30                    15
# 4                          0                       25                    10
#
# [5 rows x 24 columns]

# %% [markdown]
# 6. Try yourself
# - Download the MLBB HERO DATASET dataset from Kaggle
# - Convert the .xlsx to .csv format (you can use python or manually from numbers)
# - Upload the converted dataset to your own github <br>
# a. Import the dataset into dataframe <br>
# b. show 10 random data from dataset <br>
# c. Find out if there are any missing values in each column <br>
# d. drop the unnecessary column <br>
# e. show the roles of the hero in that dataset <br>
# f. show the most difficult hero to use<br>
# g. find out which ones has the average higher physical_atk between Fighters and Tank<br>
# h. Make a visualization showing percentages of heroes based on their role

# %%
# a
url_mlbb = r'https://raw.githubusercontent.com/belinda2201/Data-Mining/refs/heads/main/mlbb_hero.csv'
df = pd.read_csv(url_mlbb)
df.head()
# Out:
#   hero_name      role  defense_overall  offense_overall  skill_effect_overall  \
# 0   Terizla   fighter              7.0              8.0                   6.0
# 1    Martis   fighter              6.0              8.0                   5.0
# 2     Grock      tank              8.0              5.0                   6.0
# 3  Carmilla   support              5.0              5.0                   9.0
# 4   Irithel  marksman              5.0              5.0                   8.0
#
#    difficulty_overall  movement_spd  magic_defense  mana  hp_regen  \
# 0                 6.0           255             10   430        54
# 1                 5.0           260             10     0        35
# 2                 4.0           260             10   430        42
# 3                 5.0           255             10   430        39
# 4                 7.0           260             10   438        35
#
#    physical_atk  physical_defense    hp  attack_speed  mana_regen  win_rate  \
# 0           129                19  2728          0.80        21.0     47.00
# 1           128                25  2738          0.86         0.0     45.00
# 2           135                21  2819          0.81        12.0     47.69
# 3           126                25  2528          0.91        16.0     53.76
# 4           118                17  2540          0.82        15.0     51.52
#
#    pick_rate  ban_rate  release_year
# 0       0.15      0.02          2019
# 1       0.15      0.02          2018
# 2       0.14      0.02          2017
# 3       0.08      0.02          2020
# 4       0.38      0.03          2017

# %%
# b
df.sample(n = 10)
# Out:
#      hero_name      role  defense_overall  offense_overall  \
# 5       Thamuz   fighter              7.0              7.0
# 39      Badang   fighter              6.0              8.0
# 9   Minsitthar   fighter              6.0              7.0
# 96    Mathilda   support              5.0              6.0
# 41       Hilda   fighter              8.0              6.0
# 85      Khufra      tank              7.0              5.0
# 69     Balmond   fighter              7.0              6.0
# 4      Irithel  marksman              5.0              5.0
# 14        Ruby   fighter              8.0              4.0
# 63    Cecilion      mage              5.0              5.0
#
#     skill_effect_overall  difficulty_overall  movement_spd  magic_defense  \
# 5                    7.0                 6.0           250             10
# 39                   5.0                 6.0           255             10
# 9                    4.0                 3.0           260             10
# 96                   8.0                 9.0           252             10
# 41                   5.0                 4.0           260             10
# 85                   6.0                 5.0           255             10
# 69                   4.0                 3.0           260             10
# 4                    8.0                 7.0           260             10
# 14                   6.0                 7.0           260              0
# 63                   9.0                 6.0           255             10
#
#     mana  hp_regen  physical_atk  physical_defense    hp  attack_speed  \
# 5      0        37           107                22  2758          0.84
# 39     0        40           119                23  2708          0.90
# 9    380        37           121                23  2698          0.85
# 96   430        36           120                22  2551          0.80
# 41     0        42           123                24  2789          0.84
# 85   460        47           117                19  2859          0.78
# 69     0        47           119                25  2836          0.85
# 4    438        35           118                17  2540          0.82
# 14   430        30           114                23  2859          0.85
# 63  1150        34           105                20  2516          0.80
#
#     mana_regen  win_rate  pick_rate  ban_rate  release_year
# 5          0.0     47.39       0.33      0.03          2018
# 39         0.0     49.78       1.06      0.14          2019
# 9         16.0     50.54       0.17      0.03          2018
# 96         3.2     49.13       0.29      4.37          2020
# 41         0.0     47.08       0.49      0.15          2017
# 85        15.0     51.46       0.98      2.76          2019
# 69         0.0     46.30       1.96      1.22          2016
# 4         15.0     51.52       0.38      0.03          2017
# 14        14.0     52.32       0.51      0.05          2017
# 63        50.0     50.57       1.35      0.77          2020

# %%
# c
df.isnull().sum()
# Out:
# hero_name               0
# role                    0
# defense_overall         0
# offense_overall         0
# skill_effect_overall    0
# difficulty_overall      0
# movement_spd            0
# magic_defense           0
# mana                    0
# hp_regen                0
# physical_atk            0
# physical_defense        0
# hp                      0
# attack_speed            0
# mana_regen              0
# win_rate                0
# pick_rate               0
# ban_rate                0
# release_year            0
# dtype: int64

# %%
# d
df.dropna()
# Out:
#      hero_name      role  defense_overall  offense_overall  \
# 0      Terizla   fighter              7.0              8.0
# 1       Martis   fighter              6.0              8.0
# 2        Grock      tank              8.0              5.0
# 3     Carmilla   support              5.0              5.0
# 4      Irithel  marksman              5.0              5.0
# ..         ...       ...              ...              ...
# 98   Esmeralda      mage              7.0              6.0
# 99   Benedetta  assassin              5.0              6.0
# 100      Brody  marksman              6.0              9.0
# 101    Natalia  assassin              6.0              9.0
# 102   Silvanna   fighter              6.0              6.0
#
#      skill_effect_overall  difficulty_overall  movement_spd  magic_defense  \
# 0                     6.0                 6.0           255             10
# 1                     5.0                 5.0           260             10
# 2                     6.0                 4.0           260             10
# 3                     9.0                 5.0           255             10
# 4                     8.0                 7.0           260             10
# ..                    ...                 ...           ...            ...
# 98                    6.0                 4.0           240             10
# 99                    7.0                 7.0           260             10
# 100                   4.0                 7.0           253             10
# 101                   4.0                 6.0           250             10
# 102                   5.0                 4.0           255             10
#
#      mana  hp_regen  physical_atk  physical_defense    hp  attack_speed  \
# 0     430        54           129                19  2728          0.80
# 1       0        35           128                25  2738          0.86
# 2     430        42           135                21  2819          0.81
# 3     430        39           126                25  2528          0.91
# 4     438        35           118                17  2540          0.82
# ..    ...       ...           ...               ...   ...           ...
# 98    502        36           114                21  2573          0.80
# 99    460        33           128                15  2499          0.88
# 100   435        36           140                14  2490          0.96
# 101   486        35           121                18  2589          0.89
# 102   430        39           126                22  2828          0.91
#
#      mana_regen  win_rate  pick_rate  ban_rate  release_year
# 0          21.0     47.00       0.15      0.02          2019
# 1           0.0     45.00       0.15      0.02          2018
# 2          12.0     47.69       0.14      0.02          2017
# 3          16.0     53.76       0.08      0.02          2020
# 4          15.0     51.52       0.38      0.03          2017
# ..          ...       ...        ...       ...           ...
# 98         20.0     49.14       1.25     42.29          2019
# 99         16.0     52.38       0.72     49.46          2020
# 100         3.0     51.57       0.71     60.05          2020
# 101        15.0     47.76       0.41     61.29          2016
# 102        16.0     52.65       3.06      9.59          2019
#
# [103 rows x 19 columns]

# %%
# e
print(df['role'].unique())
# Out:
# ['fighter' 'tank' 'support' 'marksman' 'mage' 'assassin']

# %%
# f
most_difficult_hero = df.loc[df['difficulty_overall'].idxmax()]
print(f"The most difficult hero to use is {most_difficult_hero['hero_name']}")
# Out:
# The most difficult hero to use is Fanny

# %%
# g
fighters = df[df['role'] == 'fighter']
tanks = df[df['role'] == 'tank']

avg_physical_atk_fighters = fighters['physical_atk'].mean()
avg_physical_atk_tanks = tanks['physical_atk'].mean()

print(f"Average physical attack for Fighters: {avg_physical_atk_fighters:.8f}")
print(f"Average physical attack for Tanks: {avg_physical_atk_tanks:.8f}")

if avg_physical_atk_fighters > avg_physical_atk_tanks:
    print("Fighters have higher average physical attack than Tanks.")
elif avg_physical_atk_tanks > avg_physical_atk_fighters:
    print("Tanks have higher average physical attack than Fighters.")
else:
    print("Fighters and Tanks have the same average physical attack.")
# Out:
# Average physical attack for Fighters: 119.96551724
# Average physical attack for Tanks: 119.53333333
# Fighters have higher average physical attack than Tanks.

# %%
# h
import matplotlib.pyplot as plt

role_counts = df['role'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(role_counts, labels=role_counts.index, autopct='%1.1f%%')
plt.title('Distributions of Heroes by Role')
plt.show()

# %% [markdown]
# 7. I have a character with this specification:
# defense_overall 6.0<br>
# offense_overall 7.0<br>
# skill_effect_overall 4.0<br>
# difficulty_overall 3.0<br>
# movement_spd 250<br>
# magic_defense 9<br>
# mana 380<br>
# hp_regen 37<br>
# physical_atk 119<br>
# physical_defense 24<br>
# hp 2689<br>
# attack_speed 0.75<br>
# mana_regen 16.0<br>
#
# Please predict its role using DecisionTree classification algorithm <br>

# %%
# 7
# import library
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# Encode the 'role' column
le = LabelEncoder()
df['role_encoded'] = le.fit_transform(df['role'])

# Separate features and target variable
features = ['defense_overall', 'offense_overall', 'skill_effect_overall', 'difficulty_overall',
            'movement_spd', 'magic_defense', 'mana', 'hp_regen', 'physical_atk', 'physical_defense',
            'hp', 'attack_speed', 'mana_regen']

X = df[features]
y = df['role_encoded']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Create a Decision Tree Classifier
clf = DecisionTreeClassifier()

# Train the model
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)

# Predict the role for the given character
new_character = [[6.0, 7.0, 4.0, 3.0, 250, 9, 380, 37, 119, 24, 2689, 0.75, 16.0]]
predicted_role_encoded = clf.predict(new_character)

# Get the predicted role
predicted_role = le.inverse_transform(predicted_role_encoded)


print("Accuracy : {}".format(accuracy))
print("Predicted role for the character : {}".format(predicted_role[0]))
# Out:
# Accuracy : 0.6666666666666666
# Predicted role for the character : fighter
# c:\Users\Belinda\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# 8. Why is CSV one of the most commonly used file formats in the field of data science? <br>

# %%
# 8

print("- commonly used in data science rather than excel\n- consists of text only\n- highly compatible will almost all softwares\n- human readable")
# Out:
# - commonly used in data science rather than excel
# - consists of text only
# - highly compatible will almost all softwares
# - human readable
